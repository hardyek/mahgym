# %% [markdown]
# ## Testing `Game`

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from core.engine.main import Game

from core.agents.random import Random

# %%
agents = [Random(i) for i in range(4)]
game = Game(agents, 0)
game._initialise_game()

# %%
print(game.data['pregame']['deck'])
print(len(game.data['pregame']['deck']))
for i in range(4):
    print(game.data['pregame']['starting_hands'][i],"-", len(game.data['pregame']['starting_hands'][i]),"-", game.data['pregame']['starting_specials'][i])
print(game.data['pregame']['starting_player'])
print(game.data['pregame']['starting_wind'])
# Out:
# [43, 19, 53, 14, 62, 28, 63, 12, 18, 32, 9, 51, 34, 21, 12, 28, 24, 2, 11, 34, 31, 32, 11, 7, 4, 33, 9, 18, 1, 29, 32, 5, 13, 4, 54, 26, 25, 24, 23, 17, 12, 14, 3, 18, 1, 41, 9, 3, 31, 29, 7, 13, 24, 26, 22, 13, 27, 16, 11, 42, 3, 42, 16, 43, 15, 8, 33, 22, 17, 21, 42, 25, 31, 19, 5, 15, 8, 18, 3, 5, 52, 31, 16, 6, 43, 23, 34, 29, 4]
# 89
# [16, 9, 19, 22, 7, 1, 13, 14, 28, 2, 27, 14, 11, 28] - 14 - [64, 61]
# [27, 6, 26, 1, 2, 15, 33, 41, 4, 8, 24, 25, 19] - 13 - []
# [23, 6, 42, 41, 2, 29, 8, 5, 25, 23, 12, 17, 43] - 13 - []
# [17, 7, 32, 41, 22, 33, 26, 27, 21, 6, 34, 21, 15] - 13 - []
# 0
# 0

# %%
game._main_loop()
# Out:
# {'result': 'draw'}

# %%
game.data['actions']
# Out:
# ['B0',
#  'D0b8',
#  'E1',
#  'S1b6b7b8',
#  'D1d1',
#  'E2',
#  'T2d3',
#  'D2n6',
#  'E3',
#  'T3c9',
#  'D3w3',
#  'E4',
#  'X0f3',
#  'T0n4',
#  'D0b2',
#  'E5',
#  'T1c4',
#  'D1c9',
#  'E6',
#  'X2s2',
#  'T2b9',
#  'D2d3',
#  'E7',
#  'T3b8',
#  'D3w4',
#  'E8',
#  'X0s3',
#  'T0w4',
#  'D0c4',
#  'E9',
#  'T1c2',
#  'D1n6',
#  'E10',
#  'T2c8',
#  'D2b3',
#  'E11',
#  'T3w2',
#  'D3c9',
#  'E12',
#  'T0n9',
#  'D0w4',
#  'E13',
#  'X1f1',
#  'T1b3',
#  'D1c2',
#  'E14',
#  'T2w4',
#  'D2b5',
#  'E15',
#  'S3b5b6b7',
#  'D3n7',
#  'E16',
#  'T0b1',
#  'D0c1',
#  'E17',
#  'T1c2',
#  'D1n1',
#  'E18',
#  'T2b8',
#  'D2d2',
#  'E19',
#  'T3b4',
#  'D3n6',
#  'E20',
#  'T0n2',
#  'D0n2',
#  'E21',
#  'T1c1',
#  'D1c4',
#  'E22',
#  'T2w4',
#  'D2b3',
#  'E23',
#  'S3b1b2b3',
#  'D3d1',
#  'E24',
#  'T0w1',
#  'D0n7',
#  'E25',
#  'T1w2',
#  'D1n4',
#  'E26',
#  'T2c1',
#  'D2d3',
#  'E27',
#  'T3n7',
#  'D3c7',
#  'E28',
#  'T0n4',
#  'D0n9',
#  'E29',
#  'T1w3',
#  'D1c5',
#  'E30',
#  'T2n9',
#  'D2b8',
#  'E31',
#  'T3c8',
#  'D3w2',
#  'E32',
#  'T0n1',
#  'D0b8',
#  'E33',
#  'T1b9',
#  'D1b9',
#  'E34',
#  'P2b9',
#  'D2d1',
#  'E35',
#  'T3w2',
#  'D3b4',
#  'E36',
#  'T0n5',
#  'D0c3',
#  'E37',
#  'T1c3',
#  'D1w3',
#  'E38',
#  'T2n4',
#  'D2w4',
#  'E39',
#  'X3f4',
#  'T3d3',
#  'D3c8',
#  'E40',
#  'T0b6',
#  'D0n1',
#  'E41',
#  'T1b5',
#  'D1c3',
#  'E42',
#  'T2b4',
#  'D2c7',
#  'E43',
#  'T3b3',
#  'D3w2',
#  'E44',
#  'T0c7',
#  'D0b6',
#  'E45',
#  'T1c2',
#  'D1w3',
#  'E46',
#  'T2c4',
#  'D2c8',
#  'E47',
#  'T3n3',
#  'D3b8',
#  'E48',
#  'T0c8',
#  'D0n4',
#  'E49',
#  'T1n1',
#  'D1c2',
#  'E50',
#  'T2d1',
#  'D2d1',
#  'E51',
#  'T3n9',
#  'D3b1',
#  'E52',
#  'T0n3',
#  'D0n4',
#  'E53',
#  'T1w1',
#  'D1n1',
#  'E54',
#  'T2b9',
#  'D2n5',
#  'E55',
#  'T3n7',
#  'D3n9',
#  'E56',
#  'T0c3',
#  'D0c3',
#  'E57',
#  'S1c1c2c3',
#  'D1b5',
#  'E58',
#  'T2b4',
#  'D2b4',
#  'E59',
#  'T3b6',
#  'D3n7',
#  'E60',
#  'T0b2',
#  'D0b2',
#  'E61',
#  'T1c3',
#  'D1n8',
#  'E62',
#  'T2b7',
#  'D2n9',
#  'E63',
#  'T3c6',
#  'D3b3',
#  'E64',
#  'T0c1',
#  'D0n1',
#  'E65',
#  'T1d2',
#  'D1c3',
#  'E66',
#  'S2c1c2c3',
#  'D2w4',
#  'E67',
#  'T3n3',
#  'D3c5',
#  'E68',
#  'S0c4c5c6',
#  'D0b1',
#  'E69',
#  'T1d2',
#  'D1w1',
#  'E70',
#  'T2c6',
#  'D2c6',
#  'E71',
#  'T3d3',
#  'D3b6',
#  'E72',
#  'T0c5',
#  'D0n2',
#  'E73',
#  'T1n8',
#  'D1b3',
#  'E74',
#  'T2w3',
#  'D2b7',
#  'E75',
#  'T3b2',
#  'D3n7',
#  'E76',
#  'T0c7',
#  'D0n9',
#  'E77',
#  'T1b1',
#  'D1n8',
#  'E78',
#  'T2d2',
#  'D2n8',
#  'E79',
#  'T3b5',
#  'D3d3',
#  'E80',
#  'T0w1',
#  'D0c1',
#  'E81',
#  'T1c9',
#  'D1b5',
#  'E82',
#  'T2n5',
#  'D2d2',
#  'E83',
#  'T3c5',
#  'D3n3',
#  'E84',
#  'T0n8',
#  'D0c5',
#  'E85',
#  'T1c8',
#  'D1d2',
#  'E86',
#  'T2n3',
#  'D2b9',
#  'E87',
#  'T3n5',
#  'D3n5',
#  'E88',
#  'X0f2',
#  'T0n6',
#  'D0c9',
#  'E89',
#  'T1w1',
#  'D1d2',
#  'E90',
#  'T2c6',
#  'L0']

# %%
game.data['interrupts']
# Out:
# [[(1, 2, [26, 27, 28])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(3, 2, [21, 22, 23])],
#  [],
#  [],
#  [],
#  [(3, 2, [25, 26, 27])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(3, 2, [21, 22, 23]), (3, 2, [22, 23, 24])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(2, 0, [29, 29, 29])],
#  [],
#  [],
#  [(1, 2, [11, 12, 13])],
#  [],
#  [],
#  [],
#  [],
#  [(2, 2, [11, 12, 13])],
#  [],
#  [],
#  [(1, 2, [24, 25, 26])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(1, 2, [11, 12, 13])],
#  [],
#  [],
#  [],
#  [(1, 2, [22, 23, 24])],
#  [],
#  [],
#  [],
#  [],
#  [(2, 2, [11, 12, 13]), (2, 2, [12, 13, 14])],
#  [],
#  [(0, 2, [14, 15, 16]), (0, 2, [15, 16, 17])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(1, 0, [42, 42, 42])],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# ## Testing `Table`

# %%
import time
import matplotlib.pyplot as plt
import numpy as np

from core.engine.table import Table

# %%
times = []
stds = []
max_games = 25

for param in range(1,max_games+1):
    trial_times = []
    for _ in range(5):
        start_time = time.perf_counter()
        agents = [Random(i) for i in range(4)]
        table = Table(agents,param)
        table.play_games()
        end_time = time.perf_counter()
        trial_times.append(end_time - start_time)
    
    times.append(np.mean(trial_times))
    stds.append(np.std(trial_times))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 11
#       9 agents = [Random(i) for i in range(4)]
#      10 table = Table(agents,param)
# ---> 11 table.play_games()
#      12 end_time = time.perf_counter()
#      13 trial_times.append(end_time - start_time)
#
# File ~/Projects/mahgym/core/engine/table.py:67, in Table.play_games(self)
#      65 game = Game(self.agents, round_wind)
#      66 game._initialise_game()
# ---> 67 result = game._main_loop()
#      69 self.game_records.append(game.data)
#      71 if result['result'] == 'win':
#
# File ~/Projects/mahgym/core/engine/main.py:119, in Game._main_loop(self)
#     116 def _main_loop(self):
#     117     self.data['actions'].append(f'B{self.current_player}') # Shorthand B{player} game start on player.
# --> 119     potential_winner = utils.check_for_valid_14(self.current_player, self.players, -1) # heavenly hand
#     121     if potential_winner != -1:
#     122         scoring_info = self._game_end_check(potential_winner)
#
# File ~/Projects/mahgym/core/engine/utils.py:83, in check_for_valid_14(current_player, players, takable)
#      69 """
#      70
#      71 Checks if any players can for a form a valid set of 14 tiles (see is_valid_14) by picking up the takable tile.
#    (...)
#      79     int: The player who can declare mahjong or -1 if not.
#      80 """
#      82 if takable == -1:
# ---> 83     if is_valid_14(players[current_player].hand, players[current_player].exposed) or check_special_patterns(players[current_player].hand, True):
#      84         return current_player
#      86 else:
#
# File ~/Projects/mahgym/core/engine/utils.py:64, in is_valid_14(hand, exposed)
#      62         remaining.remove(tile)
#      63         remaining.remove(tile)
# ---> 64         if can_form_four_melds(remaining, exposed):
#      65             return True
#      66 return False
#
# File ~/Projects/mahgym/core/engine/utils.py:30, in can_form_four_melds(hand, exposed)
#      28 # Try PUNG
#      29 if hand[0] == hand[1] == hand[2]:
# ---> 30     if can_form_four_melds(hand[3:], exposed + [[hand[0]]*3]):
#      31         return True
#      33 # Try SOENG
#
# File ~/Projects/mahgym/core/engine/utils.py:38, in can_form_four_melds(hand, exposed)
#      36     for i in range(3):
#      37         new_hand.remove(hand[0] + i)
# ---> 38     if can_form_four_melds(new_hand, exposed + [[hand[0], hand[0]+1, hand[0]+2]]):
#      39         return True
#      41 return False
#
# File ~/Projects/mahgym/core/engine/utils.py:30, in can_form_four_melds(hand, exposed)
#      28 # Try PUNG
#      29 if hand[0] == hand[1] == hand[2]:
# ---> 30     if can_form_four_melds(hand[3:], exposed + [[hand[0]]*3]):
#      31         return True
#      33 # Try SOENG
#
# File ~/Projects/mahgym/core/engine/utils.py:38, in can_form_four_melds(hand, exposed)
#      36     for i in range(3):
#      37         new_hand.remove(hand[0] + i)
# ---> 38     if can_form_four_melds(new_hand, exposed + [[hand[0], hand[0]+1, hand[0]+2]]):
#      39         return True
#      41 return False
#
#     [... skipping similar frames: can_form_four_melds at line 30 (16 times), can_form_four_melds at line 38 (13 times)]
#
# File ~/Projects/mahgym/core/engine/utils.py:30, in can_form_four_melds(hand, exposed)
#      28 # Try PUNG
#      29 if hand[0] == hand[1] == hand[2]:
# ---> 30     if can_form_four_melds(hand[3:], exposed + [[hand[0]]*3]):
#      31         return True
#      33 # Try SOENG
#
#     [... skipping similar frames: can_form_four_melds at line 38 (2 times)]
#
# File ~/Projects/mahgym/core/engine/utils.py:38, in can_form_four_melds(hand, exposed)
#      36     for i in range(3):
#      37         new_hand.remove(hand[0] + i)
# ---> 38     if can_form_four_melds(new_hand, exposed + [[hand[0], hand[0]+1, hand[0]+2]]):
#      39         return True
#      41 return False
#
# File ~/Projects/mahgym/core/engine/utils.py:24, in can_form_four_melds(hand, exposed)
#      21 if sets_needed == 0:
#      22     return len(hand) == 0
# ---> 24 hand = sorted(hand)
#      25 if len(hand) < 3:
#      26     return False
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(list(range(1,max_games+1)), times, yerr=stds, fmt='o--', capsize=5, c='blue')
plt.xlabel('# Games')
plt.ylabel('Execution Time (seconds)')
plt.title("Table `play_games` execution times by # games")
plt.show()
